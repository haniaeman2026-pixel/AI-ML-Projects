# %% [markdown]
# # Handwritten Digit Recognition using CNN

# %% [markdown]
# # The objective of this project is to classify handwritten digits using Convolutional Neural Network (CNN) with the MNIST dataset.

# %% [markdown]
# # Import Libraries

# %%
# Import Libraries
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %% [markdown]
# # Load MNIST Dataset

# %%
# Load MNIST Dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# # Normalize the Dataset

# %%
# Normalize Data
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# # Reshape the Images

# %%
X_train = X_train.reshape(60000,28,28,1)
X_test = X_test.reshape(10000,28,28,1)

# %% [markdown]
# # Create CNN Model

# %%
# Create CNN Model
model = Sequential()

# %% [markdown]
# # Add Convolution Layer

# %%
# CNN Layer
model.add(Conv2D(32,(3,3), activation='relu', input_shape=(28,28,1)))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Add Max Pooling Layer

# %%
# Pooling Layer
model.add(MaxPooling2D(2,2))

# %% [markdown]
# # Flatten the Data

# %%
# Convert into 1D
model.add(Flatten())

# %% [markdown]
# # Add Dense Layer

# %%
# Dense Layer
model.add(Dense(100, activation='relu'))

# %% [markdown]
# # Add Output Layer

# %%
# Output Layer
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# # Compile the Model

# %%
# Compile Model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # Train the Model

# %%
# Train Model
model.fit(X_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 42s 22ms/step - accuracy: 0.9526 - loss: 0.1592
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 40s 21ms/step - accuracy: 0.9834 - loss: 0.0541
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 39s 21ms/step - accuracy: 0.9891 - loss: 0.0346
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 41s 21ms/step - accuracy: 0.9923 - loss: 0.0238
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - accuracy: 0.9949 - loss: 0.0165

# %% [markdown]
# # Evaluate the Model

# %%
# Check Accuracy
loss, accuracy = model.evaluate(X_test, y_test)

print("Accuracy =", accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9868 - loss: 0.0443
# Accuracy = 0.9868000149726868
